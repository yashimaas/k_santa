# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
from numba import njit
from itertools import product
from ortools.linear_solver import pywraplp
from multiprocessing import Process

# %% [markdown]
# # mst2csv

# %%
template = pd.read_csv('../data/sample_submission.csv')

# %%
template.head()
# Out:
#    family_id  assigned_day
# 0          0           100
# 1          1            99
# 2          2            98
# 3          3            97
# 4          4            96

# %%
f = open('../practice/s_s.mst', 'r')
solution = f.read()
solution = solution.split('\n')[1:]
f.close()

# %%
submit = template.copy()

# %%
for index in range(len(solution)):
    var_type = solution[index].split(' ')[0].split('[')[0]
    judge = solution[index].split(' ')[1]
    family_id = 
    if var_type == 'N':
        pass
    elif var_type == 'x':
        if judge == 1:
            
    else:
        print('''
        Error !
        ''')
# Out:
#   File "<ipython-input-6-895518b9fd44>", line 4
#     family_id =
#                 ^
# SyntaxError: invalid syntax

# %%
index = 1
solution[index].split(' ')[1]
# Out:
# '0'

# %%
family_id = solution[index].split('[')

# %%
var_type = solution[index].split(' ')[0].split('[')[0]
var_type
# Out:
# 'x'

# %%
solution
# Out:
# ['x[0,37] 0',
#  'x[0,11] 0',
#  'x[0,81] 0',
#  'x[0,32] 0',
#  'x[0,74] 0',
#  'x[0,63] 0',
#  'x[0,75] 0',
#  'x[0,9] 0',
#  'x[0,27] 0',
#  'x[1,3] 0',
#  'x[1,81] 0',
#  'x[1,4] 0',
#  'x[1,10] 0',
#  'x[1,46] 0',
#  'x[1,37] 0',
#  'x[1,5] 0',
#  'x[1,65] 0',
#  'x[1,60] 0',
#  'x[2,53] 0',
#  'x[2,24] 0',
#  'x[2,11] 0',
#  'x[2,26] 0',
#  'x[2,81] 0',
#  'x[2,9] 0',
#  'x[2,88] 0',
#  'x[2,79] 0',
#  'x[2,32] 0',
#  'x[3,94] 0',
#  'x[3,0] 0',
#  'x[3,95] 0',
#  'x[3,31] 0',
#  'x[3,5] 0',
#  'x[3,39] 0',
#  'x[3,30] 0',
#  'x[3,8] 0',
#  'x[3,58] 0',
#  'x[4,0] 0',
#  'x[4,46] 0',
#  'x[4,92] 0',
#  'x[4,25] 0',
#  'x[4,2] 0',
#  'x[4,45] 0',
#  'x[4,15] 0',
#  'x[4,41] 0',
#  'x[4,38] 0',
#  'x[5,58] 0',
#  'x[5,11] 0',
#  'x[5,2] 0',
#  'x[5,59] 0',
#  'x[5,25] 0',
#  'x[5,34] 0',
#  'x[5,49] 0',
#  'x[5,4] 0',
#  'x[5,1] 0',
#  'x[6,3] 0',
#  'x[6,0] 0',
#  'x[6,2] 0',
#  'x[6,90] 0',
#  'x[6,31] 0',
#  'x[6,38] 0',
#  'x[6,56] 0',
#  'x[6,27] 0',
#  'x[6,98] 0',
# ...
